# %%
balance = 500000
withdraw = 0
List = 0
deposite = 0
pass_word=1234
import sys
import getpass
pins = ['1111', '2222', '3333']
word = 0

print(" Welcome to Bank of America ATM")
print("Please Enter your card ")
#input("please Enter your pin number ")

#///////////
while word < 3:

    pin = str(getpass.getpass("please Enter your pin number : "))

    print('------------------	')
if pin == pins[0]:	
    break	
#???????????????????????
else:	
    word += 1	
    print('-----------	')
    print('INVALID PIN')
    print('-----------	')
    print()	
if pin == pins[1]:	
    break	
    #/////////	
else:	
    word += 1	
    print('-----------	')
    print('INVALID PIN')
    print('-----------	')
    print()	
    if pin == pins[2]:	
        break	
        #??????	
else:	
    word += 1	
    print('-----------	')
    print('INVALID PIN')
    print('-----------	')
    print()
else:
    print('------------------------')
 
    print('PIN CONSISTS OF 4 DIGITS')

    print('	------------------------	')
    word+=1
    # in	case of a valid pin- continuing, or exiting
if word== 3:
    print('	-----------------------------------	')
    print('3 UNSUCCESFUL PIN ATTEMPTS, EXITING')
    print('!!!!!YOUR CARD HAS BEEN LOCKED!!!!!')
    print('	-----------------------------------')
    exit()	
    print('	-------------------------')
    print('LOGIN SUCCESFUL, CONTINUE')
    print('	-------------------------')
    print()
    print('----------ATM SYSTEM-----------')
    #?????????????
active = True

while active:
    print("1: Deposit")
    print("2: Withdraw")
    print("3: Balance")
    print("4: Quit")

List = int(input("Please Select From The List: "))

    if List == 1:
        deposite = int(input("How much	you want	to deposit: "))
        print("Your deposited $" + str(deposite))
        balance = balance + deposite
        print("Your money add to your acword ")
        print("Thank you for used Bank of America ATM ")
        print("/////////////////////////////// ")
    elif List == 2:
        print("Your amount	is: $" + str(balance))
    while True:
        withdraw = int(input("Withdraw: $"))
    if withdraw > balance:
        print("Cannot withdraw more than available balance")
        continue
        balance = balance - withdraw
        break
        print("Thank you for used Bank of America ATM ")
        print("/////////////////////////////// ")
    elif List == 3:
        print("balance: $" + str(balance))

        print("Thank you for used Bank of America ATM ")
        print("/////////////////////////////// ")
    elif List == 4:
        sys.exit("Thank you for used Bank of America ATM")
# Out:
#   File "<ipython-input-3-625df864aab7>", line 48
#     else:
#        ^
# SyntaxError: invalid syntax
