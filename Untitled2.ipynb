# %%
    # Load the Pandas libraries with alias 'pd' 
    import pandas as pd 
    # Read data from file 'filename.csv' 
    # (in the same directory that your python process is based)
    # Control delimiters, rows, column names with read_csv (see later) 
    data = pd.read_csv("communities.csv") 
    # Preview the first 5 lines of the loaded data 
    data.head()
# Out:
#    state        communityname  population  householdsize  racepctblack  \
# 0      8         Lakewoodcity        0.19           0.33          0.02
# 1     53          Tukwilacity        0.00           0.16          0.12
# 2     24         Aberdeentown        0.00           0.42          0.49
# 3     34  Willingborotownship        0.04           0.77          1.00
# 4     42    Bethlehemtownship        0.01           0.55          0.02
#
#    racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# 0          0.90          0.12         0.17         0.34         0.47  ...
# 1          0.74          0.45         0.07         0.26         0.59  ...
# 2          0.56          0.17         0.04         0.39         0.47  ...
# 3          0.08          0.12         0.10         0.51         0.50  ...
# 4          0.95          0.09         0.05         0.38         0.38  ...
#
#    NumStreet  PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# ...

# %%
data
# Out:
#       state        communityname  population  householdsize  racepctblack  \
# 0         8         Lakewoodcity        0.19           0.33          0.02
# 1        53          Tukwilacity        0.00           0.16          0.12
# 2        24         Aberdeentown        0.00           0.42          0.49
# 3        34  Willingborotownship        0.04           0.77          1.00
# 4        42    Bethlehemtownship        0.01           0.55          0.02
# ...     ...                  ...         ...            ...           ...
# 1989     12    TempleTerracecity        0.01           0.40          0.10
# 1990      6          Seasidecity        0.05           0.96          0.46
# 1991      9        Waterburytown        0.16           0.37          0.25
# 1992     25          Walthamcity        0.08           0.51          0.06
# 1993      6          Ontariocity        0.20           0.78          0.14
#
#       racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# ...

# %%
pop = data.population

# %%
pop.mean()
# Out:
# 0.05759277833500538

# %%
#statistic for household size 

householdsize = data.householdsize
mean_household= householdsize.mean()
min_household= householdsize.min()
max_household= householdsize.max()
std_household = householdsize.std()

# %%
#statistic for racepctblack

racepctblack = data.householdsize
mean_racepctblack= racepctblack.mean()
min_racepctblack= racepctblack.min()
max_racepctblack= racepctblack.max()
std_racepctblack = racepctblack.std()

# %%
#statistic for racePctWhite

racePctWhite = data.racePctWhite
mean_racePctWhite = racePctWhite.mean()
min_racePctWhite= racePctWhite.min()
max_racePctWhite= racePctWhite.max()
std_racePctWhite = racePctWhite.std()

# %%
# statistic for racePctAsian 

racePctAsian = data.racePctAsian
mean_racePctAsian = racePctAsian.mean()
min_racePctAsian= racePctAsian.min()
max_racePctAsian= racePctAsian.max()
std_racePctAsian = racePctAsian.std()

# %%
racePctAsian
# Out:
# 0       0.12
# 1       0.45
# 2       0.17
# 3       0.12
# 4       0.09
#         ...
# 1989    0.12
# 1990    0.83
# 1991    0.04
# 1992    0.22
# 1993    0.24
# Name: racePctAsian, Length: 1994, dtype: float64

# %%
#statistic for ViolentCrimesPerPop

ViolentCrimesPerPop = data.ViolentCrimesPerPop
mean_ViolentCrimesPerPop = ViolentCrimesPerPop.mean()
min_ViolentCrimesPerPop= ViolentCrimesPerPop.min()
max_ViolentCrimesPerPop= ViolentCrimesPerPop.max()
std_ViolentCrimesPerPop = ViolentCrimesPerPop.std()

# %%
#statistic for agePct12t29


agePct12t29 = data.agePct12t29
mean_agePct12t29 = agePct12t29.mean()
min_agePct12t29= agePct12t29.min()
max_agePct12t29= agePct12t29.max()
std_agePct12t29 = agePct12t29.std()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-73a50d126c3d> in <module>
#       2
#       3 for row_t in data_transpose:
# ----> 4     print (row_t.mean())
#
# AttributeError: 'int' object has no attribute 'mean'

# %%
data2 = data.drop(['communityname', 'state'], axis=1)
data2
# Out:
#       population  householdsize  racepctblack  racePctWhite  racePctAsian  \
# 0           0.19           0.33          0.02          0.90          0.12
# 1           0.00           0.16          0.12          0.74          0.45
# 2           0.00           0.42          0.49          0.56          0.17
# 3           0.04           0.77          1.00          0.08          0.12
# 4           0.01           0.55          0.02          0.95          0.09
# ...          ...            ...           ...           ...           ...
# 1989        0.01           0.40          0.10          0.87          0.12
# 1990        0.05           0.96          0.46          0.28          0.83
# 1991        0.16           0.37          0.25          0.69          0.04
# 1992        0.08           0.51          0.06          0.87          0.22
# 1993        0.20           0.78          0.14          0.46          0.24
#
#       racePctHisp  agePct12t21  agePct12t29  agePct16t24  agePct65up  ...  \
# ...

# %%
data_transpose = data2.T

for row_t in data_transpose:
    print (row_t.mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-0db3d33923c0> in <module>
#       2
#       3 for row_t in data_transpose:
# ----> 4     print (row_t.mean())
#
# AttributeError: 'int' object has no attribute 'mean'

# %%
# Iterate over the sequence of column names in reverse order
for column in reversed(data2.columns):
# Select column contents by column name using [] operator
    columnSeriesObj = data2[column]
    data2.astype({data2[column]: 'float64'}).dtypes
    print(columnSeriesObj.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-7b55509df32e> in <module>
#       3 # Select column contents by column name using [] operator
#       4     columnSeriesObj = data2[column]
# ----> 5     data2.astype({data2[column]: 'float64'}).dtypes
#       6     print(columnSeriesObj.mean())
#       7
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1884         raise TypeError(
#    1885             "{0!r} objects are mutable, thus they cannot be"
# -> 1886             " hashed".format(self.__class__.__name__)
#    1887         )
#    1888
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
data3= data2.Series([1, 2], dtype='int32')

# %%
data2.dtypes
# Out:
# population             float64
# householdsize          float64
# racepctblack           float64
# racePctWhite           float64
# racePctAsian           float64
#                         ...
# PctSameState85         float64
# LandArea               float64
# PopDens                float64
# PctUsePubTrans         float64
# ViolentCrimesPerPop    float64
# Length: 98, dtype: object
